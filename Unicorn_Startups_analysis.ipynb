# %% [markdown]
# <a href="https://colab.research.google.com/github/SAMMMYYY233/Unicorn-Startups-analysis/blob/main/Unicorn_Startups_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries for mathmatical computation
import numpy as np
import pandas as pd
import scipy.stats as stats

#for data visualization
import seaborn as sns
import matplotlib.pyplot as plt
import plotly
import plotly.express as px
from matplotlib.pyplot import figure
from plotly.offline import init_notebook_mode , iplot
import plotly.graph_objects as go

# %matplotlib inline

# %%
#importing data

df=pd.read_csv('Startups.csv' , encoding='latin-1')
df.head()
# Out:
#    Unnamed: 0    Company Valuation ($B) Date Joined        Country  \
# 0           0  Bytedance           $140    4/7/2017          China
# 1           1     SpaceX         $100.3   12/1/2012  United States
# 2           2     Stripe            $95   1/23/2014  United States
# 3           3     Klarna          $45.6  12/12/2011         Sweden
# 4           4      Canva            $40    1/8/2018      Australia
#
#             City                      Industry  \
# 0        Beijing       Artificial intelligence
# 1      Hawthorne                         Other
# 2  San Francisco                       Fintech
# 3      Stockholm                       Fintech
# 4    Surry Hills  Internet software & services
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2        Khosla Ventures, LowercaseCapital, capitalG
# 3  Institutional Venture Partners, Sequoia Capita...
# ...

# %%
#data cleaning
df=pd.DataFrame(df)
df.rename(columns={'Date joined' : 'Date'},inplace= True)
df.rename(columns={'Valuation ($B)' : 'Valuaion'},inplace= True)
df.rename(columns={'Select Investors' : 'Investors'},inplace= True)

# %%
#list of unicorn startups in industry sector
fig=px.pie(df,names='Industry')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#year-wise analysis of companies joining Unicorn club
fig2=px.line(df, x="Company" , y="Date Joined" , title="Startups joining per year")
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#country-wise unicorn startup
India=df[df['Country']=="India"]
India
# Out:
#      Unnamed: 0                           Company Valuaion Date Joined  \
# 12           12                            BYJU's      $21   7/25/2017
# 53           53                         OYO Rooms     $9.6   9/25/2018
# 62           62                           Dream11       $8    4/9/2019
# 80           80  National Stock Exchange of India     $6.5    7/1/2020
# 83           83                          Ola Cabs     $7.5  10/27/2014
# 115         115                            Swiggy     $5.5   6/21/2018
# 126         126                            Meesho     $4.9    4/5/2021
# 153         153                              CRED    $4.01    4/6/2021
# 193         193                   Digit Insurance     $3.5   1/15/2021
# 199         199                         Unacademy    $3.44    9/2/2020
# 215         215      Eruditus Executive Education     $3.2   8/12/2021
# 221         221                             Udaan     $3.1    9/4/2018
# ...

# %%
#Based on valuation
company_wise_valuation=df.sort_values(by="Valuaion" , ascending=False)
company_wise_valuation.head(10)
# Out:
#     Unnamed: 0       Company Valuaion Date Joined        Country  \
# 2            2        Stripe      $95   1/23/2014  United States
# 53          53     OYO Rooms     $9.6   9/25/2018          India
# 45          45  ServiceTitan     $9.5  11/14/2018  United States
# 44          44    OutSystems     $9.5    6/5/2018  United States
# 46          46        HEYTEA    $9.28    7/1/2019          China
# 47          47           N26    $9.23   1/10/2019        Germany
# 48          48       Klaviyo     $9.2  11/17/2020  United States
# 49          49     Northvolt    $9.08   6/12/2019         Sweden
# 50          50        Tanium       $9   3/31/2015  United States
# 51          51     Chehaoduo       $9   3/12/2016          China
#
#              City                         Industry  \
# 2   San Francisco                          Fintech
# 53       Gurugram                           Travel
# 45       Glendale     Internet software & services
# ...

# %%
#company OYO Rooms
df[df['Company']=="OYO Rooms"]
# Out:
#     Unnamed: 0    Company Valuaion Date Joined Country      City Industry  \
# 53          53  OYO Rooms     $9.6   9/25/2018   India  Gurugram   Travel
#
#                                             investors
# 53  SoftBank Group, Sequoia Capital India,Lightspe...

# %%
#number of unicor startups in a city
df.City.value_counts().head(15)
# Out:
# San Francisco    134
# New York          81
# Beijing           62
# Shanghai          45
# London            28
# Bengaluru         25
# Shenzhen          18
# Berlin            16
# Paris             15
# Chicago           14
# Hangzhou          14
# Boston            14
# Tel Aviv          13
# Mountain View     13
# Palo Alto         11
# Name: City, dtype: int64

# %%
#unicorn startups in bengaluru
df[df.City=='Bengaluru']['Company']
# Out:
# 12                     BYJU's
# 83                   Ola Cabs
# 115                    Swiggy
# 126                    Meesho
# 153                      CRED
# 193           Digit Insurance
# 199                 Unacademy
# 221                     Udaan
# 236                  Razorpay
# 245                 ShareChat
# 252     Ola Electric Mobility
# 257                     Groww
# 299     Mobile Premier League
# 523                   CureFit
# 683                      apna
# 686    Acko General Insurance
# 709                    InMobi
# 794                 DailyHunt
# 871                 BlackBuck
# 880                   Zetwerk
# 898                   Vedantu
# 901                   Licious
# 920              Mensa Brands
# 926                  NoBroker
# 927                     Slice
# Name: Company, dtype: object

# %%
#country based unicorn startups with required information
df[df.Country=='India'][['Company','Valuaion','Industry','Date Joined']]
# Out:
#                               Company Valuaion  \
# 12                             BYJU's      $21
# 53                          OYO Rooms     $9.6
# 62                            Dream11       $8
# 80   National Stock Exchange of India     $6.5
# 83                           Ola Cabs     $7.5
# 115                            Swiggy     $5.5
# 126                            Meesho     $4.9
# 153                              CRED    $4.01
# 193                   Digit Insurance     $3.5
# 199                         Unacademy    $3.44
# 215      Eruditus Executive Education     $3.2
# 221                             Udaan     $3.1
# 231                         Delhivery       $3
# 234                         Pine Labs       $3
# 236                          Razorpay       $3
# 245                         ShareChat       $3
# 252             Ola Electric Mobility       $3
# 257                             Groww       $3
# 265                        OfBusiness       $3
# ...

# %%
#Fintech based unicorn startups in India
df[df.Country=='India'] [df[df.Country=='India'].Industry=='Fintech']['Company']
# Out:
# 80     National Stock Exchange of India
# 153                                CRED
# 193                     Digit Insurance
# 234                           Pine Labs
# 236                            Razorpay
# 257                               Groww
# 266                            BharatPe
# 304                        PolicyBazaar
# 420                    CoinSwitch Kuber
# 681                             CoinDCX
# 686              Acko General Insurance
# 927                               Slice
# Name: Company, dtype: object
